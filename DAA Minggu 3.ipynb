# %%
aList = ["John",33,"Toronto",True]
print(aList)
# Out:
# ['John', 33, 'Toronto', True]

# %%
aList = ["Mahasiswa:","Coenraad Samuel Marco Hursepuny",2021071017,"Informatika","Desain Analisis dan Algoritma", "14/9/2022", "Universitas Pembangunan Jaya"]
aList[2]
aList[6]
aList[2:4]
for datamhs in aList:
  print("UPJ " , datamhs)
# Out:
# UPJ  Mahasiswa:
# UPJ  Coenraad Samuel Marco Hursepuny
# UPJ  2021071017
# UPJ  Informatika
# UPJ  Desain Analisis dan Algoritma
# UPJ  14/9/2022
# UPJ  Universitas Pembangunan Jaya

# %%
bin_colors=["Red","Green","Blue","Yellow"]
#bin_colors[3]
for aColor in bin_colors:
  print(aColor + " Square")
# Out:
# Red Square
# Green Square
# Blue Square
# Yellow Square

# %%
bin_colors[1]
bin_colors[2:]
# Out:
# ['Blue', 'Yellow']

# %%
upj=("Universitas","Pembangunan","Jaya")
upj[1]
upj[:2]
# Out:
# ('Universitas', 'Pembangunan')

# %%
nested_tuple=(100,(200,400,600),(300),(400,800))
print (nested_tuple)
# Out:
# (100, (200, 400, 600), 300, (400, 800))

# %%
bin_colors={
    "manual_color":"Yellow",
    "approved_color":"Green",
    "refused_color":"Red"
}
#print(bin_colors)
bin_colors.get("refused_color")
# Out:
# 'Red'

# %%
data_mahasiswa={
    "Nama:"              "Coenraad Samuel Marco Hursepuny"
    " "
    "NIM:"               "2021071017"
    " "
    "Prodi:"             "Informatika"
    " "
    "Perguruan Tinggi:"  "Universitas Pembangunan Jaya"
}
print(data_mahasiswa)
# Out:
# {'Nama:Coenraad Samuel Marco Hursepuny NIM:2021071017 Prodi:Informatika Perguruan Tinggi:Universitas Pembangunan Jaya'}

# %%
ijo={"grass","leaves"}
print(ijo)
# Out:
# {'grass', 'leaves'}

# %%
red={"dandelions","leaves","fire hydrants"}
yellow={"leaves", "fire hydrants"}
green={"rose","blood","leaves","fire hydrants"}
print(yellow&green)
# Out:
#   File "<ipython-input-123-1afb018f5709>", line 1
#     yellow|red={"dandelions","fire hydrants","blood","rose","leaves"}
#                                                                      ^
# SyntaxError: can't assign to operator

# %%
import pandas as pd
df = pd.DataFrame([
    [1,"Fares",32,True],
    [2,"Elena",23,False],
    [3,"Steven",40,True]])
df.columns=["ID","Name","Age","Decision"]
df
# Out:
#    ID    Name  Age  Decision
# 0   1   Fares   32      True
# 1   2   Elena   23     False
# 2   3  Steven   40      True

# %%
import pandas as pd
mhs = pd.DataFrame([
    [1,"Informatika",50,30,20],
    [2,"Sistem Informasi",55,30,25],
    [3,"Teknik Sipil",40,30,10]])
mhs.columns=["Nomor","Prodi","Mahasiswa","Lakik","Perempuan"]
mhs
# Out:
#    Nomor             Prodi  Mahasiswa  Lakik  Perempuan
# 0      1       Informatika         50     30         20
# 1      2  Sistem Informasi         55     30         25
# 2      3      Teknik Sipil         40     30         10
